# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import json
import pandas as pd
from datetime import datetime
from copy import deepcopy
import dill
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from torchvision import transforms
import lovely_tensors as lt

import csng
from csng.CNN_Decoder import CNN_Decoder
from csng.utils import plot_losses, plot_comparison, standardize, normalize, get_mean_and_std, count_parameters, crop
from csng.losses import SSIMLoss, MSELossWithCrop, Loss
from csng.readins import MultiReadIn, FCReadIn, ConvReadIn

from data import (
    prepare_v1_dataloaders,
    SyntheticDataset,
    BatchPatchesDataLoader,
    MixedBatchLoader,
    PerSampleStoredDataset,
)

lt.monkey_patch()

DATA_PATH = os.path.join(os.environ["DATA_PATH"], "cat_V1_spiking_model", "50K_single_trial_dataset")
print(f"{DATA_PATH=}")
# Out:
# DATA_PATH='/media/jsobotka/ext_ssd/csng_data/cat_V1_spiking_model/50K_single_trial_dataset'

# %%
config = {
    "data": {
        "mixing_strategy": "parallel_min", # needed only with multiple base dataloaders
    },
    # "crop_win": (slice(15, 35), slice(15, 35)),
    "crop_win": (20, 20),
    "only_cat_v1_eval": True,
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "seed": 0,
}

print(f"... Running on {config['device']} ...")
# Out:
# ... Running on cuda ...

# %%
np.random.seed(config["seed"])
torch.manual_seed(config["seed"])
random.seed(config["seed"])

# %% [markdown]
# ## Data

# %%
dataloaders = dict()

# %% [markdown]
# ### V1 dataset (spiking model of cat V1)

# %%
config["data"]["cat_v1"] = {
    "train_path": os.path.join(DATA_PATH, "datasets", "train"),
    "val_path": os.path.join(DATA_PATH, "datasets", "val"),
    "test_path": os.path.join(DATA_PATH, "datasets", "test"),
    "image_size": [50, 50],
    "crop": False,
    "batch_size": 14,
    "stim_keys": ("stim",),
    "resp_keys": ("exc_resp", "inh_resp"),
    "return_coords": True,
    "return_ori": False,
    "coords_ori_filepath": os.path.join(DATA_PATH, "pos_and_ori.pkl"),
    "cached": False,
    "stim_normalize_mean": 46.143,
    "stim_normalize_std": 20.420,
    "resp_normalize_mean": torch.load(
        os.path.join(DATA_PATH, "responses_mean.pt")
    ),
    "resp_normalize_std": torch.load(
        os.path.join(DATA_PATH, "responses_std.pt")
    ),
}

# %%
### get data loaders
dataloaders["cat_v1"] = prepare_v1_dataloaders(**config["data"]["cat_v1"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 ### get data loaders
# ----> 2 dataloaders["cat_v1"] = prepare_v1_dataloaders(**config["data"]["cat_v1"])
#
# File ~/Desktop/Dev/CSNG/cat_v1_spiking_model/50k_dataset/data.py:64, in prepare_v1_dataloaders(train_path, val_path, test_path, image_size, crop, batch_size, return_coords, return_ori, cached, coords_ori_filepath, stim_normalize_mean, stim_normalize_std, resp_normalize_mean, resp_normalize_std, stim_keys, resp_keys)
#      61 resp_transform = torchvision.transforms.Compose(resp_transform)
#      63 ### prepare datasets
# ---> 64 train_dataset = PerSampleStoredDataset(
#      65     dataset_dir=train_path,
#      66     stim_transform=stim_transform,
#      67     resp_transform=resp_transform,
#      68     stim_keys=stim_keys,
#      69     resp_keys=resp_keys,
#      70     return_coords=return_coords,
#      71     return_ori=return_ori,
#      72     coords_ori_filepath=coords_ori_filepath,
#      73 )
#      74 val_dataset = PerSampleStoredDataset(
#      75     dataset_dir=val_path,
#      76     stim_transform=stim_transform,
#    (...)
#      82     coords_ori_filepath=coords_ori_filepath,
#      83 )
#      84 test_dataset = PerSampleStoredDataset(
#      85     dataset_dir=test_path,
#      86     stim_transform=stim_transform,
#    (...)
#      92     coords_ori_filepath=coords_ori_filepath,
#      93 )
#
# File ~/Desktop/Dev/CSNG/cat_v1_spiking_model/50k_dataset/data.py:149, in PerSampleStoredDataset.__init__(self, dataset_dir, stim_transform, resp_transform, stim_keys, resp_keys, return_coords, return_ori, coords_ori_filepath)
#     146 self.stim_transform = stim_transform if stim_transform is not None else NumpyToTensor()
#     147 self.resp_transform = resp_transform if resp_transform is not None else NumpyToTensor()
#     148 self.file_names = [
# --> 149     f_name for f_name in os.listdir(self.dataset_dir)
#     150     if f_name.endswith(".pkl") or f_name.endswith(".pickle")
#     151 ]
#     152 self.stim_keys = stim_keys
#     153 self.resp_keys = resp_keys
#
# KeyboardInterrupt:

# %%
### show data
datapoint = next(iter(dataloaders["cat_v1"]["val"]))
stim, resp, coords = datapoint.images, datapoint.responses, datapoint.neuron_coords
coords = coords.float()
print(
    f"{stim.shape=}, {resp.shape=}"
    f"\n{stim.min()=}, {stim.max()=}"
    f"\n{resp.min()=}, {resp.max()=}"
    f"\n{stim.mean()=}, {stim.std()=}"
    f"\n{resp.mean()=}, {resp.std()=}"
    f"\n{coords.shape=}, {coords.dtype=}"
    f"\n{coords.min()=}, {coords.max()=}"
    # f"\n{ori.min()=}, {ori.max()=}"
)

### plot sample data
sample_idx = 0
fig = plt.figure(figsize=(14, 6))
ax = fig.add_subplot(131)
ax.imshow(stim[sample_idx].squeeze().unsqueeze(-1), cmap="gray")

ax = fig.add_subplot(132)
ax.imshow(crop(stim[sample_idx], config["crop_win"]).squeeze().unsqueeze(-1), cmap="gray")

# ax = fig.add_subplot(133)
# ax.imshow(resp[0].view(125, 375).squeeze(0).unsqueeze(-1), cmap="gray")

### bin the neuronal responses based on their neuron coordinates and sum within each bin -> 2D grid of vals
H, W = stim.shape[-2:] # the size of the grid
n_x_bins, n_y_bins = 20, 20 # number of bins in each dimension
min_x, max_x, min_y, max_y = coords[sample_idx,:,0].min().item(), coords[sample_idx,:,0].max().item(), coords[sample_idx,:,1].min().item(), coords[sample_idx,:,1].max().item()
x_bins = torch.linspace(min_x, max_x, n_x_bins + 1)
y_bins = torch.linspace(min_y, max_y, n_y_bins + 1)
binned_resp = torch.zeros(n_y_bins, n_x_bins)
for i in range(n_x_bins):
    for j in range(n_y_bins):
        ### mask of the neurons in the bin
        mask = (x_bins[i] <= coords[sample_idx,:,0]) &\
               (coords[sample_idx,:,0] < x_bins[i + 1]) &\
               (y_bins[j] <= coords[sample_idx,:,1]) &\
               (coords[sample_idx,:,1] < y_bins[j + 1])
        binned_resp[j,i] = resp[sample_idx, mask.cpu()].sum(0)
ax = fig.add_subplot(133)
ax.imshow(binned_resp.squeeze().cpu(), cmap="gray")
plt.show()

plt.show()
# Out:
# stim.shape=torch.Size([14, 1, 50, 50]), resp.shape=torch.Size([14, 46875])
# stim.min()=tensor[] -2.260, stim.max()=tensor[] 2.637
# resp.min()=tensor[] -2.408, resp.max()=tensor[] 17.007
# stim.mean()=tensor[] 0.039, stim.std()=tensor[] 1.200
# resp.mean()=tensor[] -0.007, resp.std()=tensor[] 1.075
# coords.shape=torch.Size([14, 46875, 2]), coords.dtype=torch.float32
# coords.min()=tensor[] -2.500, coords.max()=tensor[] 2.500

# %% [markdown]
# ### Synthetic data (different stimuli dataset -> encoder -> neuronal responses)

# %%
resp_mean = torch.from_numpy(np.load(os.path.join(DATA_PATH, "synthetic_data", "responses_mean.npy"))).float()
resp_std = torch.from_numpy(np.load(os.path.join(DATA_PATH, "synthetic_data", "responses_std.npy"))).float()

config["data"]["syn_data"] = {
    "dataset": {
        "stim_transform": transforms.Normalize(
            mean=114.457,
            std=51.356,
        ),
        "resp_transform": csng.utils.Normalize(
            mean=resp_mean,
            std=resp_std,
        ),
    },
    "dataloader": {
        "batch_size": 20,
        "shuffle": True,
    }
}

# %%
syn_datasets = {
    "train": PerSampleStoredDataset(
        dataset_dir=os.path.join(DATA_PATH, "synthetic_data", "processed", "train"),
        **config["data"]["syn_data"]["dataset"]
    ),
    "val": PerSampleStoredDataset(
        dataset_dir=os.path.join(DATA_PATH, "synthetic_data", "processed", "val"),
        **config["data"]["syn_data"]["dataset"]
    ),
    "test": PerSampleStoredDataset(
        dataset_dir=os.path.join(DATA_PATH, "synthetic_data", "processed", "test"),
        **config["data"]["syn_data"]["dataset"]
    ),
}

dataloaders["syn_data"] = {
    "train": DataLoader(
        dataset=syn_datasets["train"],
        **config["data"]["syn_data"]["dataloader"],
    ),
    "val": DataLoader(
        dataset=syn_datasets["val"],
        **config["data"]["syn_data"]["dataloader"],
    ),
    "test": DataLoader(
        dataset=syn_datasets["test"],
        **config["data"]["syn_data"]["dataloader"],
    ),
}

# %%
### calculate statistics

### for stimuli
# syn_stats = get_mean_and_std(dataset=syn_dataset, verbose=True)
# syn_stats

### for responses
# from csng.utils import RunningStats

# stats = RunningStats(num_components=10000, lib="torch", device="cuda")
# for i, (s, r) in enumerate(syn_dataloader):
#     stats.update(r)
#     if i % 200 == 0:
#         print(f"{i}: {r.mean()=} {r.std()=} {stats.get_mean()=} {stats.get_std()=}")

### save
# torch.save(stats.get_mean(), os.path.join(DATA_PATH, "responses_mean_from_syn_dataset.pt"))
# torch.save(stats.get_std(), os.path.join(DATA_PATH, "responses_std_from_syn_dataset.pt"))


### generate preprocessed synthetic data
# import pickle
# target_dir = os.path.join(DATA_PATH, "synthetic_data", "processed")

# for data_split in ("train", "val", "test"):
#     print(data_split)
#     ### get the whole batch from dataloaders and save to disk
#     sample_idx = 0
#     for stim, resp in syn_dataloaders[data_split]:
#         if sample_idx % 2000 == 0:
#             print("  ", sample_idx)
        
#         for i in range(stim.shape[0]):
#             sample_idx += 1
#             save_to = os.path.join(target_dir, data_split, f"{sample_idx}.pickle")

#             data = {"stim": stim[i].cpu(), "resp": resp[i].cpu()}
#             with open(save_to, "wb") as f:
#                 pickle.dump(data, f)

# %%
### show data
syn_stim, syn_resp = next(iter(dataloaders["syn_data"]["val"]))
print(
    f"{syn_stim.shape=}, {syn_resp.shape=}"
    f"\n{syn_stim.min()=}, {syn_stim.max()=}"
    f"\n{syn_resp.min()=}, {syn_resp.max()=}"
    f"\n{syn_stim.mean()=}, {syn_stim.std()=}"
    f"\n{syn_resp.mean()=}, {syn_resp.std()=}"
)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(131)
ax.imshow(syn_stim.cpu()[0].squeeze().unsqueeze(-1), cmap="gray")

ax = fig.add_subplot(132)
ax.imshow(crop(syn_stim.cpu()[0], config["crop_win"]).squeeze().unsqueeze(-1), cmap="gray")

ax = fig.add_subplot(133)
ax.imshow(syn_resp.cpu()[0].view(100, 100).squeeze(0).unsqueeze(-1), cmap="gray")

plt.show()

# %% [markdown]
# ### Synthetic data (V1 data stimuli -> encoder -> neuronal responses)

# %%
### load
resp_mean = torch.from_numpy(np.load(os.path.join(DATA_PATH, "synthetic_data_v1_encoder", "responses_mean_original.npy"))).float()
resp_std = torch.from_numpy(np.load(os.path.join(DATA_PATH, "synthetic_data_v1_encoder", "responses_std_original.npy"))).float()

config["data"]["syn_data_v1_enc"] = {
    "dataset": {
        "stim_transform": transforms.Normalize(
            mean=0,
            std=1,
        ),
        "resp_transform": csng.utils.Normalize(
            mean=resp_mean,
            std=resp_std,
        ),
    },
    "dataloader": {
        "batch_size": 30,
        "shuffle": True,
    }
}

# %%
syn_datasets_v1_encoder = {
    "train": PerSampleStoredDataset(
        dataset_dir=os.path.join(DATA_PATH, "synthetic_data_v1_encoder", "train"),
        **config["data"]["syn_data_v1_enc"]["dataset"]
    ),
    "val": PerSampleStoredDataset(
        dataset_dir=os.path.join(DATA_PATH, "synthetic_data_v1_encoder", "val"),
        **config["data"]["syn_data_v1_enc"]["dataset"]
    ),
    "test": PerSampleStoredDataset(
        dataset_dir=os.path.join(DATA_PATH, "synthetic_data_v1_encoder", "test"),
        **config["data"]["syn_data_v1_enc"]["dataset"]
    ),
}

dataloaders["syn_data_v1_enc"] = {
    "train": DataLoader(
        dataset=syn_datasets_v1_encoder["train"],
        **config["data"]["syn_data_v1_enc"]["dataloader"],
    ),
    "val": DataLoader(
        dataset=syn_datasets_v1_encoder["val"],
        **config["data"]["syn_data_v1_enc"]["dataloader"],
    ),
    "test": DataLoader(
        dataset=syn_datasets_v1_encoder["test"],
        **config["data"]["syn_data_v1_enc"]["dataloader"],
    ),
}

# %%
### show data
syn_stim_v1_enc, syn_resp_v1_enc = next(iter(dataloaders["syn_data_v1_enc"]["val"]))
print(
    f"{syn_stim_v1_enc.shape=}, {syn_resp_v1_enc.shape=}"
    f"\n{syn_stim_v1_enc.min()=}, {syn_stim_v1_enc.max()=}"
    f"\n{syn_resp_v1_enc.min()=}, {syn_resp_v1_enc.max()=}"
    f"\n{syn_stim_v1_enc.mean()=}, {syn_stim_v1_enc.std()=}"
    f"\n{syn_resp_v1_enc.mean()=}, {syn_resp_v1_enc.std()=}"
)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(131)
ax.imshow(syn_stim_v1_enc.cpu()[0].squeeze().unsqueeze(-1), cmap="gray")

ax = fig.add_subplot(132)
ax.imshow(crop(syn_stim_v1_enc.cpu()[0], config["crop_win"]).squeeze().unsqueeze(-1), cmap="gray")

ax = fig.add_subplot(133)
ax.imshow(syn_resp_v1_enc.cpu()[0].view(100, 100).squeeze(0).unsqueeze(-1), cmap="gray")

plt.show()

# %% [markdown]
# ## Decoder

# %%
def train(model, dataloader, opter, loss_fn, config, verbose=True):
    model.train()
    train_loss = 0
    n_batches = len(dataloader)
    
    ### run
    # for batch_idx, (stim, resp, coords, ori) in enumerate(dataloader):
    for batch_idx, b in enumerate(dataloader):
        opter.zero_grad()
        loss = 0

        ### combine from all data keys
        for data_key, (stim, resp, neuron_coords) in b.items():
            ### data
            stim = stim.to(config["device"])
            resp = resp.to(config["device"])
            neuron_coords = neuron_coords.float().to(config["device"])
        
            ### train
            stim_pred = model(resp, data_key=data_key, neuron_coords=neuron_coords)
            loss += loss_fn(stim_pred, stim, phase="train")
            model.set_additional_loss(
                inp={
                    "resp": resp,
                    "stim": stim,
                    "neuron_coords": neuron_coords,
                    "data_key": data_key,
                }, out={
                    "stim_pred": stim_pred,
                },
            )
            loss += model.get_additional_loss(data_key=data_key)
        
        ### update
        loss /= len(b)
        loss.backward()
        opter.step()

        ### log
        train_loss += loss.item()
        if verbose and batch_idx % 100 == 0:
            print(f"Training progress: [{batch_idx}/{n_batches} ({100. * batch_idx / n_batches:.0f}%)]"
                  f"  Loss: {loss.item():.6f}")

    train_loss /= n_batches
    return train_loss

# %%
def val(model, dataloader, loss_fn, config):
    model.eval()
    val_loss = 0
    
    with torch.no_grad():
        for batch_idx, b in enumerate(dataloader):

            loss = 0

            ### combine from all data keys
            for data_key, (stim, resp, neuron_coords) in b.items():
                ### data
                stim = stim.to(config["device"])
                resp = resp.to(config["device"])
                neuron_coords = neuron_coords.float().to(config["device"])
            
                ### predict
                stim_pred = model(resp, data_key=data_key, neuron_coords=neuron_coords)
                loss += loss_fn(stim_pred, stim, phase="test")
                model.set_additional_loss(
                    inp={
                        "resp": resp,
                        "stim": stim,
                        "neuron_coords": neuron_coords,
                        "data_key": data_key,
                    }, out={
                        "stim_pred": stim_pred,
                    },
                )
                loss += model.get_additional_loss(data_key=data_key)

            ### log
            loss /= len(b)
            val_loss += loss.item()

    val_loss /= len(dataloader)
    return val_loss

# %%
def get_dataloaders(config, dataloaders, only_cat_v1_eval=True):
    ### get dataloaders to mix
    dataloaders_to_mix = [dl for dl in dataloaders.values()]

    ### get dataloaders
    train_dataloader = MixedBatchLoader(
        dataloaders=[dl["train"] for dl in dataloaders_to_mix],
        mixing_strategy=config["data"]["mixing_strategy"],
        device=config["device"],
        data_keys=["cat_v1" for _ in dataloaders_to_mix],
        return_pupil_center=False,
    )
    val_dataloader = MixedBatchLoader(
        dataloaders=[dl["val"] for dl in dataloaders_to_mix] \
            if not only_cat_v1_eval else [dataloaders["cat_v1"]["val"]],
        mixing_strategy=config["data"]["mixing_strategy"],
        device=config["device"],
        data_keys=["cat_v1" for _ in dataloaders_to_mix],
        return_pupil_center=False,
    )

    return train_dataloader, val_dataloader

# %%
config["decoder"] = {
    "model": {
        "readins_config": [
            {
                "data_key": "cat_v1",
                "in_shape": resp.shape[-1],
                "decoding_objective_config": None,
                "layers": [
                    (ConvReadIn, {
                        "H": 8,
                        "W": 8,
                        "shift_coords": False,
                        "learn_grid": True,
                        "grid_l1_reg": 8e-3,
                        "grid_net_config": {
                            "in_channels": 3, # x, y, resp
                            "layers_config": [("fc", 64), ("fc", 128), ("fc", 8*8)],
                            "act_fn": nn.LeakyReLU,
                            "out_act_fn": nn.Identity,
                            "dropout": 0.2,
                            "batch_norm": False,
                        },
                        "in_channels_group_size": 3,
                        "pointwise_conv_config": {
                            "in_channels": resp.shape[-1],
                            "out_channels": 144,
                            "act_fn": nn.LeakyReLU,
                            "bias": False,
                            "batch_norm": True,
                        },
                        "gauss_blur": False,
                        "gauss_blur_kernel_size": 7,
                        "gauss_blur_sigma": "fixed", # "fixed", "single", "per_neuron"
                        # "gauss_blur_sigma": "per_neuron", # "fixed", "single", "per_neuron"
                        "gauss_blur_sigma_init": 1.5,
                    }),

                #     (FCReadIn, {
                #         "in_shape": d.n_neurons,
                #         "layers_config": [
                #             ("fc", 288),
                #             ("unflatten", 1, (2, 9, 16)),
                #         ],
                #         "act_fn": nn.LeakyReLU,
                #         "out_act_fn": nn.Identity,
                #         "batch_norm": True,
                #         "dropout": 0.15,
                #         "out_channels": 2,
                #     }),
                ],
            }
        ],
        "core_cls": CNN_Decoder,
        "core_config": {
            "resp_shape": [144],
            "stim_shape": list(stim.shape[1:]),
            "layers": [
                ### for conv_readin
                ("deconv", 128, 7, 2, 1),
                ("deconv", 64, 5, 1, 1),
                ("deconv", 32, 4, 1, 1),
                ("deconv", 1, 3, 1, 0),
            ],
            "act_fn": nn.ReLU,
            "out_act_fn": nn.Identity,
            "dropout": 0.25,
            "batch_norm": True,
        },
    },
    "opter_cls": torch.optim.Adam,
    "opter_kwargs": {
        # "lr": 0.001,
        "lr": 1e-4,
    },
    "loss": {
        # "loss_fn": nn.MSELoss(),
        # "loss_fn": MSELossWithCrop(window=config["crop_win"]),
        "loss_fn": SSIMLoss(
            window=config["crop_win"],
            log_loss=True,
            inp_normalized=True,
            inp_standardized=False,
        ),
        "l1_reg_mul": 0,
        "l2_reg_mul": 5e-5,
        "con_reg_mul": 0,
        # "con_reg_mul": 1,
        "con_reg_loss_fn": SSIMLoss(
            window=config["crop_win"],
            log_loss=True,
            inp_normalized=True,
            inp_standardized=False,
        ),
        "encoder": None,
        # "encoder": encoder,
    },
    "n_epochs": 200,
    "load_ckpt": None,
    # "load_ckpt": {
    #     "run_name": "2023-08-25_09-07-46",
    #     "ckpt_path": os.path.join(DATA_PATH, "models", "cnn", "2023-08-25_09-07-46", "ckpt", "decoder_40.pt"),
    # },
    "save_run": True,
}

decoder = MultiReadIn(**config["decoder"]["model"]).to(config["device"])
opter = config["decoder"]["opter_cls"](decoder.parameters(), **config["decoder"]["opter_kwargs"])
loss_fn = Loss(model=decoder, config=config["decoder"]["loss"])
# Out:
# [WARNING] Setting nonnegative_ssim to True as log_loss is set to True.
# [WARNING] Setting nonnegative_ssim to True as log_loss is set to True.
# [WARNING] resp_shape in core_config will be overwritten by the output of the last readin layer (shape 144)

# %%
### prepare checkpointing
if config["decoder"]["save_run"]:
    ### save config
    run_name = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    ckpts_dir = os.path.join(os.environ["DATA_PATH"], "mouse_v1_sensorium22",
                             "models", "cat_v1_pretraining")
    config["dir"] = os.path.join(ckpts_dir, run_name)
    os.makedirs(config["dir"], exist_ok=True)
    with open(os.path.join(config["dir"], "config.json"), "w") as f:
        json.dump(config, f, indent=4, default=str)
    os.makedirs(os.path.join(config["dir"], "samples"), exist_ok=True)
    os.makedirs(os.path.join(config["dir"], "ckpt"), exist_ok=True)
    make_sample_path = lambda epoch, prefix: os.path.join(
        config["dir"], "samples", f"{prefix}stim_comparison_{epoch}e.png"
    )

    print(f"Run name: {run_name}\nRun dir: {config['dir']}")
else:
    make_sample_path = lambda epoch, prefix: None
    print("WARNING: Not saving the run and the config.")
# Out:
# Run name: 2024-02-27_19-17-39
# Run dir: /media/jsobotka/ext_ssd/csng_data/mouse_v1_sensorium22/models/cat_v1_pretraining/2024-02-27_19-17-39

# %%
### load ckpt
if config["decoder"]["load_ckpt"] is not None:
    ### load ckpt
    run_name = config["decoder"]["load_ckpt"]["name"]  # "2023-08-25_09-07-46"
    ckpt = torch.load(os.path.join(DATA_PATH, "models", run_name, "ckpt", "decoder_40.pt"), pickle_module=dill)

    history = ckpt["history"]
    config = ckpt["config"]
    best = ckpt["best"]

    decoder = CNN_Decoder(**config["decoder"]["model"]).to(config["device"])
    decoder.load_state_dict(ckpt["decoder"])

    opter = config["decoder"]["opter_cls"](decoder.parameters(), **config["decoder"]["opter_kwargs"])
    opter.load_state_dict(ckpt["opter"])

    loss_fn = config["decoder"]["loss_fn"]() if type(config["decoder"]["loss_fn"]) == type else config["decoder"]["loss_fn"]

    make_sample_path = lambda epoch, prefix: os.path.join(
        config["dir"], "samples", f"{prefix}stim_comparison_{epoch}e.png"
    )
else:
    history = {"train_loss": [], "val_loss": []}
    best = {"val_loss": np.inf, "epoch": 0, "model": None}

# %%
### print model
with torch.no_grad():
    print(decoder(resp.to(config["device"]), data_key="cat_v1", neuron_coords=coords.float().to(config["device"])).shape)
print(f"Number of parameters: {count_parameters(decoder)}")

decoder

# %%
### train
s, e = len(history["train_loss"]), config["decoder"]["n_epochs"]
for epoch in range(s, e):
    print(f"[{epoch + 1}/{e}]")

    ### train and val
    train_dataloader, val_dataloader = get_dataloaders(
        config=config,
        dataloaders=dataloaders,
        only_cat_v1_eval=config["only_cat_v1_eval"],
    )
    train_loss = train(
        model=decoder,
        dataloader=train_dataloader,
        opter=opter,
        loss_fn=loss_fn,
        config=config,
    )
    val_loss = val(
        model=decoder,
        dataloader=val_dataloader,
        loss_fn=loss_fn,
        config=config,
    )

    ### save best model
    if val_loss < best["val_loss"]:
        best["val_loss"] = val_loss
        best["epoch"] = epoch
        best["model"] = deepcopy(decoder.state_dict())

    ### log
    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    print(f"{train_loss=:.4f}, {val_loss=:.4f}")

    ### plot reconstructions
    stim_pred = decoder(resp[:8].to(config["device"]), neuron_coords=coords[:8].to(config["device"]), data_key="cat_v1").detach()
    if "cat_v1" in config["data"] and config["data"]["cat_v1"]["crop"] == False:
        plot_comparison(target=crop(stim[:8], config["crop_win"]).cpu(), pred=crop(stim_pred[:8], config["crop_win"]).cpu(), save_to=make_sample_path(epoch, ""))
    else:
        plot_comparison(target=stim[:8].cpu(), pred=stim_pred[:8].cpu(), save_to=make_sample_path(epoch, "no_crop_"))

    ### plot losses + save ckpt
    if epoch % 5 == 0 and epoch > 0:
        plot_losses(history=history, epoch=epoch, save_to=os.path.join(config["dir"], f"losses_{epoch}.png") if config["decoder"]["save_run"] else None)

        ### ckpt
        if config["decoder"]["save_run"]:
            torch.save({
                "decoder": decoder.state_dict(),
                "opter": opter.state_dict(),
                "history": history,
                "config": config,
                "best": best,
            }, os.path.join(config["dir"], "ckpt", f"decoder_{epoch}.pt"), pickle_module=dill)
# Out:
# [1/200]
# Training progress: [0/3214 (0%)]  Loss: 3.923252
# Training progress: [100/3214 (3%)]  Loss: 2.354138
# Training progress: [200/3214 (6%)]  Loss: 2.833009
# Training progress: [300/3214 (9%)]  Loss: 2.676896
# Training progress: [400/3214 (12%)]  Loss: 2.594616
# Training progress: [500/3214 (16%)]  Loss: 2.861916
# Training progress: [600/3214 (19%)]  Loss: 2.594607
# Training progress: [700/3214 (22%)]  Loss: 2.163157
# Training progress: [800/3214 (25%)]  Loss: 2.739385
# Training progress: [900/3214 (28%)]  Loss: 2.183886
# Training progress: [1000/3214 (31%)]  Loss: 2.708504
# Training progress: [1100/3214 (34%)]  Loss: 2.113220
# Training progress: [1200/3214 (37%)]  Loss: 2.227873
# Training progress: [1300/3214 (40%)]  Loss: 2.206005
# Training progress: [1400/3214 (44%)]  Loss: 1.733092
# Training progress: [1500/3214 (47%)]  Loss: 1.425652
# Training progress: [1600/3214 (50%)]  Loss: 1.160799
# Training progress: [1700/3214 (53%)]  Loss: 1.119960
# Training progress: [1800/3214 (56%)]  Loss: 1.143812
# Training progress: [1900/3214 (59%)]  Loss: 1.130609
# Training progress: [2000/3214 (62%)]  Loss: 0.927759
# Training progress: [2100/3214 (65%)]  Loss: 0.937949
# Training progress: [2200/3214 (68%)]  Loss: 1.015991
# Training progress: [2300/3214 (72%)]  Loss: 0.845487
# Training progress: [2400/3214 (75%)]  Loss: 0.819465
# Training progress: [2500/3214 (78%)]  Loss: 0.815542
# Training progress: [2600/3214 (81%)]  Loss: 0.872073
# Training progress: [2700/3214 (84%)]  Loss: 0.905134
# Training progress: [2800/3214 (87%)]  Loss: 0.789663
# Training progress: [2900/3214 (90%)]  Loss: 0.729290
# Training progress: [3000/3214 (93%)]  Loss: 0.722123
# Training progress: [3100/3214 (96%)]  Loss: 0.853369
# Training progress: [3200/3214 (100%)]  Loss: 0.843842
# train_loss=1.6248, val_loss=0.6645
# Saved to /media/jsobotka/ext_ssd/csng_data/mouse_v1_sensorium22/models/cat_v1_pretraining/2024-02-27_19-17-39/samples/stim_comparison_0e.png.
# [2/200]
# Training progress: [0/3214 (0%)]  Loss: 0.678386
# Training progress: [100/3214 (3%)]  Loss: 0.696813
# Training progress: [200/3214 (6%)]  Loss: 0.684451
# Training progress: [300/3214 (9%)]  Loss: 0.599268
# Training progress: [400/3214 (12%)]  Loss: 0.654268
# Training progress: [500/3214 (16%)]  Loss: 0.740603
# Training progress: [600/3214 (19%)]  Loss: 0.688795
# Training progress: [700/3214 (22%)]  Loss: 0.660775
# Training progress: [800/3214 (25%)]  Loss: 0.742447
# Training progress: [900/3214 (28%)]  Loss: 0.641315
# Training progress: [1000/3214 (31%)]  Loss: 0.635130
# Training progress: [1100/3214 (34%)]  Loss: 0.813996
# Training progress: [1200/3214 (37%)]  Loss: 0.663523
# Training progress: [1300/3214 (40%)]  Loss: 0.553344
# Training progress: [1400/3214 (44%)]  Loss: 0.756118
# Training progress: [1500/3214 (47%)]  Loss: 0.594138
# Training progress: [1600/3214 (50%)]  Loss: 0.629959
# Training progress: [1700/3214 (53%)]  Loss: 0.633823
# Training progress: [1800/3214 (56%)]  Loss: 0.570003
# Training progress: [1900/3214 (59%)]  Loss: 0.622229
# Training progress: [2000/3214 (62%)]  Loss: 0.575378
# Training progress: [2100/3214 (65%)]  Loss: 0.556182
# Training progress: [2200/3214 (68%)]  Loss: 0.569686
# Training progress: [2300/3214 (72%)]  Loss: 0.578594
# Training progress: [2400/3214 (75%)]  Loss: 0.488817
# Training progress: [2500/3214 (78%)]  Loss: 0.600180
# Training progress: [2600/3214 (81%)]  Loss: 0.590177
# Training progress: [2700/3214 (84%)]  Loss: 0.470992
# Training progress: [2800/3214 (87%)]  Loss: 0.496290
# Training progress: [2900/3214 (90%)]  Loss: 0.582039
# Training progress: [3000/3214 (93%)]  Loss: 0.500662
# Training progress: [3100/3214 (96%)]  Loss: 0.527811
# Training progress: [3200/3214 (100%)]  Loss: 0.547779
# train_loss=0.6213, val_loss=0.5044
# Saved to /media/jsobotka/ext_ssd/csng_data/mouse_v1_sensorium22/models/cat_v1_pretraining/2024-02-27_19-17-39/samples/stim_comparison_1e.png.
# [3/200]
# Training progress: [0/3214 (0%)]  Loss: 0.512897
# Training progress: [100/3214 (3%)]  Loss: 0.419432
# Training progress: [200/3214 (6%)]  Loss: 0.452684
# Training progress: [300/3214 (9%)]  Loss: 0.513394
# Training progress: [400/3214 (12%)]  Loss: 0.612518
# Training progress: [500/3214 (16%)]  Loss: 0.505150
# Training progress: [600/3214 (19%)]  Loss: 0.445342
# Training progress: [700/3214 (22%)]  Loss: 0.521155
# Training progress: [800/3214 (25%)]  Loss: 0.496231
# Training progress: [900/3214 (28%)]  Loss: 0.535676
# Training progress: [1000/3214 (31%)]  Loss: 0.433277
# Training progress: [1100/3214 (34%)]  Loss: 0.459353
# Training progress: [1200/3214 (37%)]  Loss: 0.485671
# Training progress: [1300/3214 (40%)]  Loss: 0.442839
# Training progress: [1400/3214 (44%)]  Loss: 0.544391
# Training progress: [1500/3214 (47%)]  Loss: 0.514250
# Training progress: [1600/3214 (50%)]  Loss: 0.436215
# Training progress: [1700/3214 (53%)]  Loss: 0.516311
# Training progress: [1800/3214 (56%)]  Loss: 0.459377
# Training progress: [1900/3214 (59%)]  Loss: 0.413195
# Training progress: [2000/3214 (62%)]  Loss: 0.410419
# Training progress: [2100/3214 (65%)]  Loss: 0.467695
# Training progress: [2200/3214 (68%)]  Loss: 0.537768
# Training progress: [2300/3214 (72%)]  Loss: 0.548257
# Training progress: [2400/3214 (75%)]  Loss: 0.438772
# Training progress: [2500/3214 (78%)]  Loss: 0.502717
# Training progress: [2600/3214 (81%)]  Loss: 0.486756
# Training progress: [2700/3214 (84%)]  Loss: 0.480066
# Training progress: [2800/3214 (87%)]  Loss: 0.378374
# Training progress: [2900/3214 (90%)]  Loss: 0.442585
# Training progress: [3000/3214 (93%)]  Loss: 0.503673
# Training progress: [3100/3214 (96%)]  Loss: 0.417730
# Training progress: [3200/3214 (100%)]  Loss: 0.444864
# train_loss=0.4860, val_loss=0.4881
# Saved to /media/jsobotka/ext_ssd/csng_data/mouse_v1_sensorium22/models/cat_v1_pretraining/2024-02-27_19-17-39/samples/stim_comparison_2e.png.
# [4/200]
# Training progress: [0/3214 (0%)]  Loss: 0.385042
# Training progress: [100/3214 (3%)]  Loss: 0.487159
# Training progress: [200/3214 (6%)]  Loss: 0.446967
# Training progress: [300/3214 (9%)]  Loss: 0.426070
# Training progress: [400/3214 (12%)]  Loss: 0.357409
# Training progress: [500/3214 (16%)]  Loss: 0.402687
# Training progress: [600/3214 (19%)]  Loss: 0.527871
# Training progress: [700/3214 (22%)]  Loss: 0.470481
# Training progress: [800/3214 (25%)]  Loss: 0.332763
# Training progress: [900/3214 (28%)]  Loss: 0.405437
# Training progress: [1000/3214 (31%)]  Loss: 0.490210
# Training progress: [1100/3214 (34%)]  Loss: 0.360221
# Training progress: [1200/3214 (37%)]  Loss: 0.459447
# Training progress: [1300/3214 (40%)]  Loss: 0.398856
# Training progress: [1400/3214 (44%)]  Loss: 0.331974
# Training progress: [1500/3214 (47%)]  Loss: 0.485511
# Training progress: [1600/3214 (50%)]  Loss: 0.453596
# Training progress: [1700/3214 (53%)]  Loss: 0.475510
# Training progress: [1800/3214 (56%)]  Loss: 0.423615
# Training progress: [1900/3214 (59%)]  Loss: 0.368777
# Training progress: [2000/3214 (62%)]  Loss: 0.474566
# Training progress: [2100/3214 (65%)]  Loss: 0.462779
# Training progress: [2200/3214 (68%)]  Loss: 0.447654
# Training progress: [2300/3214 (72%)]  Loss: 0.447211
# Training progress: [2400/3214 (75%)]  Loss: 0.419074
# Training progress: [2500/3214 (78%)]  Loss: 0.377472
# Training progress: [2600/3214 (81%)]  Loss: 0.447689
# Training progress: [2700/3214 (84%)]  Loss: 0.463872
# Training progress: [2800/3214 (87%)]  Loss: 0.432634
# Training progress: [2900/3214 (90%)]  Loss: 0.442903
# Training progress: [3000/3214 (93%)]  Loss: 0.429538
# Training progress: [3100/3214 (96%)]  Loss: 0.456552
# Training progress: [3200/3214 (100%)]  Loss: 0.357962
# train_loss=0.4233, val_loss=0.4078
# Saved to /media/jsobotka/ext_ssd/csng_data/mouse_v1_sensorium22/models/cat_v1_pretraining/2024-02-27_19-17-39/samples/stim_comparison_3e.png.
# [5/200]
# Training progress: [0/3214 (0%)]  Loss: 0.425524
# Training progress: [100/3214 (3%)]  Loss: 0.327655
# Training progress: [200/3214 (6%)]  Loss: 0.317483
# Training progress: [300/3214 (9%)]  Loss: 0.353509
# Training progress: [400/3214 (12%)]  Loss: 0.416039
# Training progress: [500/3214 (16%)]  Loss: 0.378631
# Training progress: [600/3214 (19%)]  Loss: 0.386009
# Training progress: [700/3214 (22%)]  Loss: 0.359115
# Training progress: [800/3214 (25%)]  Loss: 0.354754
# Training progress: [900/3214 (28%)]  Loss: 0.534711
# Training progress: [1000/3214 (31%)]  Loss: 0.381950
# Training progress: [1100/3214 (34%)]  Loss: 0.433900
# Training progress: [1200/3214 (37%)]  Loss: 0.402640
# Training progress: [1300/3214 (40%)]  Loss: 0.386195
# Training progress: [1400/3214 (44%)]  Loss: 0.434951
# Training progress: [1500/3214 (47%)]  Loss: 0.436392
# Training progress: [1600/3214 (50%)]  Loss: 0.411105
# Training progress: [1700/3214 (53%)]  Loss: 0.360038
# Training progress: [1800/3214 (56%)]  Loss: 0.401749
# Training progress: [1900/3214 (59%)]  Loss: 0.358571
# Training progress: [2000/3214 (62%)]  Loss: 0.418652
# Training progress: [2100/3214 (65%)]  Loss: 0.349648
# Training progress: [2200/3214 (68%)]  Loss: 0.379955
# Training progress: [2300/3214 (72%)]  Loss: 0.375008
# Training progress: [2400/3214 (75%)]  Loss: 0.370010
# Training progress: [2500/3214 (78%)]  Loss: 0.367764
# Training progress: [2600/3214 (81%)]  Loss: 0.402854
# Training progress: [2700/3214 (84%)]  Loss: 0.325253
# Training progress: [2800/3214 (87%)]  Loss: 0.344050
# Training progress: [2900/3214 (90%)]  Loss: 0.380832
# Training progress: [3000/3214 (93%)]  Loss: 0.369667
# Training progress: [3100/3214 (96%)]  Loss: 0.546797
# Training progress: [3200/3214 (100%)]  Loss: 0.427111
# train_loss=0.3839, val_loss=0.3851
# Saved to /media/jsobotka/ext_ssd/csng_data/mouse_v1_sensorium22/models/cat_v1_pretraining/2024-02-27_19-17-39/samples/stim_comparison_4e.png.
# [6/200]
# Training progress: [0/3214 (0%)]  Loss: 0.389279
# Training progress: [100/3214 (3%)]  Loss: 0.393946
# Training progress: [200/3214 (6%)]  Loss: 0.378400
# Training progress: [300/3214 (9%)]  Loss: 0.351174
# Training progress: [400/3214 (12%)]  Loss: 0.357909
# Training progress: [500/3214 (16%)]  Loss: 0.364307
# Training progress: [600/3214 (19%)]  Loss: 0.352524
# Training progress: [700/3214 (22%)]  Loss: 0.413469
# Training progress: [800/3214 (25%)]  Loss: 0.303063
# Training progress: [900/3214 (28%)]  Loss: 0.406378
# Training progress: [1000/3214 (31%)]  Loss: 0.336513
# Training progress: [1100/3214 (34%)]  Loss: 0.399798
# Training progress: [1200/3214 (37%)]  Loss: 0.400390
# Training progress: [1300/3214 (40%)]  Loss: 0.304501
# Training progress: [1400/3214 (44%)]  Loss: 0.342106
# Training progress: [1500/3214 (47%)]  Loss: 0.389207
# Training progress: [1600/3214 (50%)]  Loss: 0.351257
# Training progress: [1700/3214 (53%)]  Loss: 0.341516
# Training progress: [1800/3214 (56%)]  Loss: 0.340361
# Training progress: [1900/3214 (59%)]  Loss: 0.352895
# Training progress: [2000/3214 (62%)]  Loss: 0.379148
# Training progress: [2100/3214 (65%)]  Loss: 0.321932
# Training progress: [2200/3214 (68%)]  Loss: 0.417149
# Training progress: [2300/3214 (72%)]  Loss: 0.421881
# Training progress: [2400/3214 (75%)]  Loss: 0.347803
# Training progress: [2500/3214 (78%)]  Loss: 0.358107
# Training progress: [2600/3214 (81%)]  Loss: 0.352675
# Training progress: [2700/3214 (84%)]  Loss: 0.366932
# Training progress: [2800/3214 (87%)]  Loss: 0.444809
# Training progress: [2900/3214 (90%)]  Loss: 0.391387
# Training progress: [3000/3214 (93%)]  Loss: 0.387562
# Training progress: [3100/3214 (96%)]  Loss: 0.352554
# Training progress: [3200/3214 (100%)]  Loss: 0.375641
# train_loss=0.3540, val_loss=0.3684
# Saved to /media/jsobotka/ext_ssd/csng_data/mouse_v1_sensorium22/models/cat_v1_pretraining/2024-02-27_19-17-39/samples/stim_comparison_5e.png.
# [7/200]
# Training progress: [0/3214 (0%)]  Loss: 0.276444
# Training progress: [100/3214 (3%)]  Loss: 0.345293
# Training progress: [200/3214 (6%)]  Loss: 0.400885
# Training progress: [300/3214 (9%)]  Loss: 0.347577
# Training progress: [400/3214 (12%)]  Loss: 0.325384
# Training progress: [500/3214 (16%)]  Loss: 0.318087
# Training progress: [600/3214 (19%)]  Loss: 0.307752
# Training progress: [700/3214 (22%)]  Loss: 0.318224
# Training progress: [800/3214 (25%)]  Loss: 0.301520
# Training progress: [900/3214 (28%)]  Loss: 0.346851
# Training progress: [1000/3214 (31%)]  Loss: 0.340654
# Training progress: [1100/3214 (34%)]  Loss: 0.374697
# Training progress: [1200/3214 (37%)]  Loss: 0.339719
# Training progress: [1300/3214 (40%)]  Loss: 0.343592
# Training progress: [1400/3214 (44%)]  Loss: 0.362971
# Training progress: [1500/3214 (47%)]  Loss: 0.323584
# Training progress: [1600/3214 (50%)]  Loss: 0.328015
# Training progress: [1700/3214 (53%)]  Loss: 0.309679
# Training progress: [1800/3214 (56%)]  Loss: 0.324522
# Training progress: [1900/3214 (59%)]  Loss: 0.380931
# Training progress: [2000/3214 (62%)]  Loss: 0.349614
# Training progress: [2100/3214 (65%)]  Loss: 0.346138
# Training progress: [2200/3214 (68%)]  Loss: 0.325927
# Training progress: [2300/3214 (72%)]  Loss: 0.271870
# Training progress: [2400/3214 (75%)]  Loss: 0.376846
# Training progress: [2500/3214 (78%)]  Loss: 0.396297
# Training progress: [2600/3214 (81%)]  Loss: 0.354114
# Training progress: [2700/3214 (84%)]  Loss: 0.356047
# Training progress: [2800/3214 (87%)]  Loss: 0.309017
# Training progress: [2900/3214 (90%)]  Loss: 0.328820
# Training progress: [3000/3214 (93%)]  Loss: 0.336445
# Training progress: [3100/3214 (96%)]  Loss: 0.286368
# Training progress: [3200/3214 (100%)]  Loss: 0.353713
# train_loss=0.3317, val_loss=0.3582
# Saved to /media/jsobotka/ext_ssd/csng_data/mouse_v1_sensorium22/models/cat_v1_pretraining/2024-02-27_19-17-39/samples/stim_comparison_6e.png.
# [8/200]
# Training progress: [0/3214 (0%)]  Loss: 0.319901
# Training progress: [100/3214 (3%)]  Loss: 0.259430
# Training progress: [200/3214 (6%)]  Loss: 0.281958
# Training progress: [300/3214 (9%)]  Loss: 0.354771
# Training progress: [400/3214 (12%)]  Loss: 0.296245
# Training progress: [500/3214 (16%)]  Loss: 0.305425
# Training progress: [600/3214 (19%)]  Loss: 0.407719
# Training progress: [700/3214 (22%)]  Loss: 0.329167
# Training progress: [800/3214 (25%)]  Loss: 0.286643
# Training progress: [900/3214 (28%)]  Loss: 0.294706
# Training progress: [1000/3214 (31%)]  Loss: 0.297410
# Training progress: [1100/3214 (34%)]  Loss: 0.302510
# Training progress: [1200/3214 (37%)]  Loss: 0.292438
# Training progress: [1300/3214 (40%)]  Loss: 0.301646
# Training progress: [1400/3214 (44%)]  Loss: 0.313752
# Training progress: [1500/3214 (47%)]  Loss: 0.280116
# Training progress: [1600/3214 (50%)]  Loss: 0.333001
# Training progress: [1700/3214 (53%)]  Loss: 0.310067
# Training progress: [1800/3214 (56%)]  Loss: 0.321918
# Training progress: [1900/3214 (59%)]  Loss: 0.295449
# Training progress: [2000/3214 (62%)]  Loss: 0.327007
# Training progress: [2100/3214 (65%)]  Loss: 0.293650
# Training progress: [2200/3214 (68%)]  Loss: 0.293585
# Training progress: [2300/3214 (72%)]  Loss: 0.306740
# Training progress: [2400/3214 (75%)]  Loss: 0.277414
# Training progress: [2500/3214 (78%)]  Loss: 0.303886
# Training progress: [2600/3214 (81%)]  Loss: 0.341717
# Training progress: [2700/3214 (84%)]  Loss: 0.325581
# Training progress: [2800/3214 (87%)]  Loss: 0.326585
# Training progress: [2900/3214 (90%)]  Loss: 0.317663
# Training progress: [3000/3214 (93%)]  Loss: 0.305770
# Training progress: [3100/3214 (96%)]  Loss: 0.283429
# Training progress: [3200/3214 (100%)]  Loss: 0.286982
# train_loss=0.3156, val_loss=0.3554
# Saved to /media/jsobotka/ext_ssd/csng_data/mouse_v1_sensorium22/models/cat_v1_pretraining/2024-02-27_19-17-39/samples/stim_comparison_7e.png.
# [9/200]
# Training progress: [0/3214 (0%)]  Loss: 0.296229
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <cell line: 3>()
#       6 ### train and val
#       7 train_dataloader, val_dataloader = get_dataloaders(
#       8     config=config,
#       9     dataloaders=dataloaders,
#      10     only_cat_v1_eval=config["only_cat_v1_eval"],
#      11 )
# ---> 12 train_loss = train(
#      13     model=decoder,
#      14     dataloader=train_dataloader,
#      15     opter=opter,
#      16     loss_fn=loss_fn,
#      17     config=config,
#      18 )
#      19 val_loss = val(
#      20     model=decoder,
#      21     dataloader=val_dataloader,
#      22     loss_fn=loss_fn,
#      23     config=config,
#      24 )
#      26 ### save best model
#
# Input In [8], in train(model, dataloader, opter, loss_fn, config, verbose)
#       4 n_batches = len(dataloader)
#       6 ### run
#       7 # for batch_idx, (stim, resp, coords, ori) in enumerate(dataloader):
# ----> 8 for batch_idx, b in enumerate(dataloader):
#       9     opter.zero_grad()
#      10     loss = 0
#
# File ~/Desktop/Dev/CSNG/cat_v1_spiking_model/50k_dataset/data.py:647, in MixedBatchLoader.__next__(self)
#     645     out = self._get_sequential()
#     646 elif self.mixing_strategy in ("parallel_min", "parallel_max"):
# --> 647     out = self._get_parallel()
#     648 else:
#     649     raise NotImplementedError
#
# File ~/Desktop/Dev/CSNG/cat_v1_spiking_model/50k_dataset/data.py:577, in MixedBatchLoader._get_parallel(self)
#     575 datapoint = next(dataloader_iter["dl"])
#     576 _stim, _resp = datapoint.images, datapoint.responses
# --> 577 to_return[dataloader_iter["data_key"]] = [_stim.to(self.device), _resp.to(self.device)]
#     578 if self.return_neuron_coords:
#     579     if self.neuron_coords is None:
#
# KeyboardInterrupt:

# %%
torch.save({
    "decoder": decoder.state_dict(),
    "opter": opter.state_dict(),
    "history": history,
    "config": config,
    "best": best,
}, os.path.join(f"decoder.pt"), pickle_module=dill)

# %%
print(f"Best val loss: {best['val_loss']:.4f} at epoch {best['epoch']}")

### save final ckpt
if config["decoder"]["save_run"]:
    torch.save({
        "decoder": decoder.state_dict(),
        "opter": opter.state_dict(),
        "history": history,
        "config": config,
        "best": best,
    }, os.path.join(config["dir"], f"decoder.pt"), pickle_module=dill)

### plot reconstructions of the final model
decoder.load_state_dict(best["model"])
stim_pred_best = decoder(resp[:8].to(config["device"]), neuron_coords=coords[:8].to(config["device"]), data_key="cat_v1").detach()
plot_comparison(
    target=crop(stim[:8], config["crop_win"]).cpu(),
    pred=crop(stim_pred_best[:8], config["crop_win"]).cpu(),
    save_to=os.path.join(config["dir"], "stim_comparison_best.png")
)

### plot losses
plot_losses(
    history=history,
    save_to=None if not config["decoder"]["save_run"] else os.path.join(config["dir"], f"losses.png"),
)
# Out:
# Best val loss: 0.3554 at epoch 7
# Saved to /media/jsobotka/ext_ssd/csng_data/mouse_v1_sensorium22/models/cat_v1_pretraining/2024-02-27_19-17-39/stim_comparison_best.png.
